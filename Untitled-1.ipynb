# %%
print(run_test(screen, images, 1000, 0))
# Out:
# Traceback (most recent call last):
#   File "/home/pablo/.vscode-server/extensions/ms-python.python-2025.18.0-linux-x64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'run_test' is not defined

# %%
15*60
# Out:
# 900

# %%
results = [(0, True, 100), (0, False, 150), (2, False, 200)]

# %%
with open("result.csv", newline="") as f:
    writer = csv.writer(f, delimiter=" ")
    writer.writerows(results)
# Out:
# Traceback (most recent call last):
#   File "/home/pablo/.vscode-server/extensions/ms-python.python-2025.18.0-linux-x64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# FileNotFoundError: [Errno 2] No such file or directory: 'result.csv'

# %%
with open("result.csv", "w", newline="") as f:
    writer = csv.writer(f, delimiter=" ")
    writer.writerows(results)
# Out:
# Traceback (most recent call last):
#   File "/home/pablo/.vscode-server/extensions/ms-python.python-2025.18.0-linux-x64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in <module>
# NameError: name 'csv' is not defined. Did you forget to import 'csv'

# %%
from typing import Optional
import pygame
import random
import csv
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
with open("result.csv", "w", newline="") as f:
    writer = csv.writer(f, delimiter=" ")
    writer.writerows(results)

# %%
filename = "data/result0.csv"

# %%
me) as f:
        reader = csv.reader(f, delimiter=" ")
        results = list(rea
# Out:
# Traceback (most recent call last):
#   File "/home/pablo/.vscode-server/extensions/ms-python.python-2025.18.0-linux-x64/python_files/python_server.py", line 134, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1
#     me) as f:
#       ^
# SyntaxError: unmatched ')'

# %%
with open(filename) as f:
    reader = csv.reader(f, delimiter=" ")
    results = list(reader)

# %%
results
# Out:
# [['0', '1', '855'], ['0', '1', '1016'], ['0', '1', '1120'], ['0', '1', '1194'], ['25', '0', '1798'], ['25', '1', '1324'], ['25', '1', '1433'], ['25', '1', '3514'], ['50', '0', '1232'], ['50', '0', '1450'], ['50', '0', '1959'], ['50', '1', '1420'], ['75', '0', '1697'], ['75', '0', '2272'], ['75', '0', '3663'], ['75', '0', '5000'], ['100', '0', '1498'], ['100', '0', '1687'], ['100', '0', '2008'], ['100', '0', '3147']]

# %%
results = []
with open(filename) as f:
    reader = csv.reader(f, delimiter=" ")
    for line in reader:
        results.append(list(map(int, line)))

# %%
results
# Out:
# [[0, 1, 855], [0, 1, 1016], [0, 1, 1120], [0, 1, 1194], [25, 0, 1798], [25, 1, 1324], [25, 1, 1433], [25, 1, 3514], [50, 0, 1232], [50, 0, 1450], [50, 0, 1959], [50, 1, 1420], [75, 0, 1697], [75, 0, 2272], [75, 0, 3663], [75, 0, 5000], [100, 0, 1498], [100, 0, 1687], [100, 0, 2008], [100, 0, 3147]]

# %%
for i,j,k in results:
    print (i)
